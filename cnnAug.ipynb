# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
import random
import os

# %%
# 資料夾路徑（請確保結構為 train/men, train/women, test/men, test/women）
train_dir = 'train'
test_dir = 'test'

# 圖片大小與參數
img_height, img_width = 128, 128
batch_size = 32


train_datagen = ImageDataGenerator(
    rescale=1./255,             # 基本正規化
    rotation_range=15,          # 隨機旋轉 ±15 度
    width_shift_range=0.1,      # 隨機水平平移 ±10%
    # height_shift_range=0.1,     # 隨機垂直平移 ±10%
    zoom_range=0.1,             # 隨機縮放 ±10%
    # horizontal_flip=True,       # 隨機水平翻轉（對臉部有效）
    fill_mode='nearest'         # 空白像素填補方式
)

test_datagen = ImageDataGenerator(rescale=1./255)

# 建立資料生成器
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary'
)

# 🧠 純粹 CNN 模型（無正則化、無資料增強）
model = models.Sequential([
    layers.Conv2D(64, (3, 3), activation='relu', input_shape=(img_height, img_width, 3)),
    layers.MaxPooling2D(pool_size=(2, 2)),

    layers.Conv2D(32, (3, 3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),

    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid')  # 二元分類輸出
])

# 編譯模型
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# 🏋️‍♂️ 開始訓練
history = model.fit(
    train_generator,
    epochs=10,
    validation_data=test_generator
)
# Out:
# Found 220 images belonging to 2 classes.
# Found 80 images belonging to 2 classes.
# Epoch 1/10
# 7/7 [==============================] - 15s 2s/step - loss: 1.1858 - accuracy: 0.5318 - val_loss: 0.7114 - val_accuracy: 0.5000
# Epoch 2/10
# 7/7 [==============================] - 13s 2s/step - loss: 0.6924 - accuracy: 0.4455 - val_loss: 0.6929 - val_accuracy: 0.5000
# Epoch 3/10
# 7/7 [==============================] - 13s 2s/step - loss: 0.6929 - accuracy: 0.5136 - val_loss: 0.6929 - val_accuracy: 0.5250
# Epoch 4/10
# 7/7 [==============================] - 13s 2s/step - loss: 0.6932 - accuracy: 0.5136 - val_loss: 0.6918 - val_accuracy: 0.5750
# Epoch 5/10
# 7/7 [==============================] - 13s 2s/step - loss: 0.6919 - accuracy: 0.6045 - val_loss: 0.6913 - val_accuracy: 0.5125
# Epoch 6/10
# 7/7 [==============================] - 13s 2s/step - loss: 0.6897 - accuracy: 0.5545 - val_loss: 0.6870 - val_accuracy: 0.5750
# Epoch 7/10
# 7/7 [==============================] - 13s 2s/step - loss: 0.6781 - accuracy: 0.6136 - val_loss: 0.6810 - val_accuracy: 0.5625
# Epoch 8/10
# 7/7 [==============================] - 13s 2s/step - loss: 0.6660 - accuracy: 0.6045 - val_loss: 0.6885 - val_accuracy: 0.5375
# Epoch 9/10
# 7/7 [==============================] - 13s 2s/step - loss: 0.6540 - accuracy: 0.6182 - val_loss: 0.6793 - val_accuracy: 0.6375
# Epoch 10/10
# 7/7 [==============================] - 13s 2s/step - loss: 0.6301 - accuracy: 0.6773 - val_loss: 0.7375 - val_accuracy: 0.5250
